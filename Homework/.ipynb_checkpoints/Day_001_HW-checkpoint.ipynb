# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)
#
# # 作業一
# ### 我所選的的competition為LANL Earthquake Prediction
# #### 1. 你選的這組資料為何重要?
# 因為地震所能產生的災害是可以非常巨大的，因此如果可以預測出地震何時、何地發生以及規模有多大，就可以提早預防，甚至為重要的設施做好保護措施
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者為Los Alamos National Laboratory、Pennstate Department of Geosciences、Purdue University Department of Physics & Astronomy，是透過他們的實驗室所收集的資料而來
#
# #### 3. 蒐集而來的資料型態為何
# 資料型態為 signal與time，藉由訊號的收發時間，預測出地震的發生時間與實驗室的誤差為何
#
# #### 4. 這組資料想解決的問題如何評估
# 是利用迴歸分系中的MAE來分析the predicted time remaining before the next lab earthquake and the act remaining time.
#
# # 作業二
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我認為提升業績應該與載客量有關係，在同一段時間內，能載客的數量越多，業績就會提升
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 載客的時間、乘客平均搭乘時間、搭乘地點等資料會影響判斷的結果，可透過政府公開資料收集
#
# #### 3. 蒐集而來的資料型態為何
# 時間、地點、距離
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 利用變數之間的Correlation強度來驗證

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = sum((y-yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean squared error is 235.168
